# %% [markdown]
# <a href="https://colab.research.google.com/github/kamaliahewitt/bte320/blob/main/BTE_320_In_Class_Assignments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sales = float(input("Enter sales ($):"))
cost = sales * 0.40
gross_profit = sales - cost
print("sales: $", sales)
print("cost of goods sold: $", cost)
print("gross profit: $", gross_profit)
# Out:
# Enter sales ($):12000
# sales: $ 12000.0
# cost of goods sold: $ 4800.0
# gross profit: $ 7200.0

# %%
x = float(input("enter the first number:"))
y = float(input("enter the second number:"))
operator = input("enter an operator (+, -, *, /):")

result = None # Initialize result to avoid NameError if no condition is met before the final print

if operator == "+":
  result = x + y
elif operator == "-":
  result = x - y
elif operator == "*":
  result = x * y
elif operator == "/":
  if y != 0:
    result = x / y
  else:
    result = "Error: Division by zero"
else:
  result = "invalid operator"

print("Result:", result)
# Out:
# enter the first number:10
# enter the second number:5
# enter an operator (+, -, *, /):*
# Result: 50.0

# %%
for hours in range(1, 9):
  fee = 5 + 2.5 * hours
  print(hours, fee)
# Out:
# 1 7.5
# 2 10.0
# 3 12.5
# 4 15.0
# 5 17.5
# 6 20.0
# 7 22.5
# 8 25.0

# %%
for hours in range(1, 9):
  fee = 5 + 2.5 * hours
  if fee < 10:
    fee = 10
  elif fee > 20:
    fee = 20
  print(hours, fee)
# Out:
# 1 10
# 2 10.0
# 3 12.5
# 4 15.0
# 5 17.5
# 6 20.0
# 7 20
# 8 20
